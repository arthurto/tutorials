# %%
import matplotlib.pyplot as plt
import numpy as np
import scienceplots

plt.style.use('science')

# %%
# genterating the data
x = np.linspace(0,360,100)
y = np.sin(2*np.pi*x/360)
plt.plot(x,y)
plt.xlabel("$\\varphi^\dagger$")
plt.ylabel("Sin(x)")
plt.show()

# %%
ϕ
